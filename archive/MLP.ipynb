# %%
from helper_lin import get_all_data, get_mult_data, get_sub_data, get_labels

# %%
# make nn deterministic
import torch
import numpy as np
import random

def set_seed(seed=42):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

# %%
import torch.nn as nn
import torch.optim as optim
class LassoBrainMLP(nn.Module):
    def __init__(self):
        super(LassoBrainMLP, self).__init__()
        # Input is now 100
        self.layer1 = nn.Linear(100, 32) 
        self.relu = nn.ReLU()
        self.output = nn.Linear(32, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.relu(self.layer1(x))
        return self.sigmoid(self.output(x))
    
model = LassoBrainMLP()
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)
l1_lambda = 0.005 # Increase this to make the map "sparser"

# %%
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold

def train_mlp_model(X_avg, y_avg):
    # Select top 100 statistically significant connections
    selector = SelectKBest(score_func=f_classif, k=100)
    X_reduced = selector.fit_transform(X_avg, y_avg)
    selected_indices = selector.get_support(indices=True)

    # Scale the data (Lasso/MLPs require this!)
    scaler = StandardScaler()
    X_final = scaler.fit_transform(X_reduced)

    all_test_preds = []
    all_test_labels = []
    all_test_probs = []

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    print(f"Starting Stratified 5-Fold CV with LASSO regularization...")

    # 2. Change loop to use skf.split
    for fold, (train_idx, test_idx) in enumerate(skf.split(X_final, y_avg)):
        # Split Data
        X_train, X_test = X_final[train_idx], X_final[test_idx]
        y_train, y_test = y_avg[train_idx], y_avg[test_idx]

        # Convert to Tensors
        X_train_t = torch.tensor(X_train, dtype=torch.float32)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
        X_test_t = torch.tensor(X_test, dtype=torch.float32)

        # Initialize model/optimizer
        model = LassoBrainMLP() 
        criterion = torch.nn.BCELoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
        l1_lambda = 0.005 

        # 3. Train on the training folds (e.g., 24 participants)
        model.train()
        for epoch in range(100):
            optimizer.zero_grad()
            outputs = model(X_train_t)
            bce_loss = criterion(outputs, y_train_t)
            l1_penalty = torch.norm(model.layer1.weight, 1)
            total_loss = bce_loss + (l1_lambda * l1_penalty)
            total_loss.backward()
            optimizer.step()

        # 4. Test on the test fold (e.g., 6 participants)
        model.eval()
        with torch.no_grad():
            test_probs_t = model(X_test_t) # This is now a tensor of size (6, 1)
            
            # Convert probabilities to binary predictions (0 or 1)
            # .numpy().flatten() converts tensor to a simple array
            preds = (test_probs_t > 0.5).float().numpy().flatten()
            
            # Use .extend because we are adding multiple values at once
            all_test_probs.extend(test_probs_t.numpy().flatten())
            all_test_preds.extend(preds)
            all_test_labels.extend(y_test)
        
        print(f"Fold {fold+1} complete.")

    # 5. Final Report
    final_acc = accuracy_score(all_test_labels, all_test_preds)
    print(f"\nFinal Stratified K-Fold Accuracy: {final_acc * 100:.2f}%")

    model.eval()
    # Get the absolute sum of weights for each of the 100 features
    # This tells us how much the model "trusts" each brain connection
    feature_weights = torch.abs(model.layer1.weight).sum(dim=0).detach().numpy()
    
    return all_test_labels, all_test_probs, all_test_preds, feature_weights, selected_indices

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
def plt_roc_curve(all_test_labels, all_test_probs):
    # 1. Convert lists to numpy arrays first
    labels_array = np.array(all_test_labels)
    probs_array = np.array(all_test_probs)

    # 2. Flatten them to ensure they are 1D (removes that extra dimension)
    labels_flat = labels_array.flatten()
    probs_flat = probs_array.flatten()

    # After the loop finishes:
    fpr, tpr, thresholds = roc_curve(labels_flat, probs_flat)
    roc_auc = auc(fpr, tpr)

    # Plotting
    plt.figure(figsize=(7, 7))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--') # Random guess line
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate (1 - Specificity)')
    plt.ylabel('True Positive Rate (Sensitivity)')
    plt.title('Receiver Operating Characteristic (ROC) - MLP')
    plt.legend(loc="lower right")
    plt.grid(alpha=0.3)
    plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

def plt_confusion_matrix(all_test_labels, all_test_preds):
    # 1. Classification Report (Precision, Recall, F1)
    # 0 = TD, 1 = MLD
    target_names = ['Typical Development', 'Math Learning Difficulty']
    print("\nDetailed Classification Report:")
    print(classification_report(all_test_labels, all_test_preds, target_names=target_names))

    # 2. Confusion Matrix
    cm = confusion_matrix(all_test_labels, all_test_preds)

    # 3. Visualization
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=target_names, yticklabels=target_names)
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix: MLP with LASSO (LOOCV)')
    plt.show()

# %%
def get_winning_conn(feature_weights, selected_indices):
    # Get indices of features with non-zero weights (the 'winners')
    threshold = 1e-4 
    winning_meta_indices = np.where(feature_weights > threshold)[0]
    winning_raw_indices = selected_indices[winning_meta_indices]

    print(f"{len(winning_raw_indices)} connections survived.")

# %%
def get_roi_names(index, n_rois=400):
    """Converts a vector index back to ROI pairs (Schaefer 400)."""
    # Create an empty upper triangle matrix
    tri_indices = np.triu_indices(n_rois, k=1)
    roi_a_idx = tri_indices[0][index]
    roi_b_idx = tri_indices[1][index]
    return roi_a_idx, roi_b_idx

def get_top_10_conn(feature_weights, selected_indices):
    # 3. Get the Top 10 Indices
    # argsort gives indices of features from smallest to largest weight
    # [-10:] takes the last 10 (the largest), and [::-1] puts them in descending order
    top_10_meta_indices = np.argsort(feature_weights)[-10:][::-1]

    # Map these meta-indices (0-99) back to the original connectivity indices (0-79799)
    # Assuming 'selected_indices' is the array from your SelectKBest step
    top_10_raw_indices = selected_indices[top_10_meta_indices]

    # 4. Print and Store Results
    print(f"--- Top 10 Connectivity Fingerprints ---")
    top_connections_info = []
    labels = get_labels()
    for i, raw_idx in enumerate(top_10_raw_indices):
        roi_a_idx, roi_b_idx = get_roi_names(raw_idx)
        
        label_a = (labels[roi_a_idx])
        label_b = (labels[roi_b_idx])
        score = feature_weights[top_10_meta_indices[i]]
        
        print(f"Rank {i+1}: Score {score:.4f} | {label_a} <-> {label_b}")
        
        top_connections_info.append({
            'rank': i+1,
            'score': score,
            'roi_a': label_a,
            'roi_b': label_b,
            'indices': (roi_a_idx, roi_b_idx)
        })
    return top_connections_info

# %% [markdown]
# # MLP for All Tasks

# %%
X_avg, y_avg = get_all_data()
all_test_labels, all_test_probs, all_test_preds, feature_weights, selected_indices = train_mlp_model(X_avg, y_avg)
# Out:
# Starting Stratified 5-Fold CV with LASSO regularization...
# Fold 1 complete.
# Fold 2 complete.
# Fold 3 complete.
# Fold 4 complete.
# Fold 5 complete.
#
# Final Stratified K-Fold Accuracy: 83.33%

# %%
plt_roc_curve(all_test_labels, all_test_probs)

# %%
plt_confusion_matrix(all_test_labels, all_test_preds)
# Out:
# Detailed Classification Report:
#                           precision    recall  f1-score   support
#
#      Typical Development       0.86      0.80      0.83        15
# Math Learning Difficulty       0.81      0.87      0.84        15
#
#                 accuracy                           0.83        30
#                macro avg       0.83      0.83      0.83        30
#             weighted avg       0.83      0.83      0.83        30

# %%
get_winning_conn(feature_weights, selected_indices)
# Out:
# 100 connections survived.

# %%
all_top_10_conn = get_top_10_conn(feature_weights, selected_indices)
# Out:
# --- Top 10 Connectivity Fingerprints ---
# [fetch_atlas_schaefer_2018] Dataset found in /Users/jchong058/nilearn_data/schaefer_2018
# Rank 1: Score 1.5622 | 7Networks_RH_SomMot_38 <-> 7Networks_RH_Cont_PFCl_8
# Rank 2: Score 1.4894 | 7Networks_LH_DorsAttn_Post_6 <-> 7Networks_LH_Default_pCunPCC_3
# Rank 3: Score 1.2529 | 7Networks_RH_SomMot_17 <-> 7Networks_RH_DorsAttn_FEF_1
# Rank 4: Score 0.9369 | 7Networks_LH_Vis_16 <-> 7Networks_LH_DorsAttn_Post_14
# Rank 5: Score 0.8473 | 7Networks_LH_Default_Par_1 <-> 7Networks_RH_Vis_2
# Rank 6: Score 0.8130 | 7Networks_LH_Cont_PFCl_5 <-> 7Networks_RH_Limbic_TempPole_5
# Rank 7: Score 0.6419 | 7Networks_RH_Vis_26 <-> 7Networks_RH_DorsAttn_Post_9
# Rank 8: Score 0.6220 | 7Networks_LH_Limbic_TempPole_5 <-> 7Networks_LH_Cont_PFCl_1
# Rank 9: Score 0.3802 | 7Networks_LH_Vis_25 <-> 7Networks_RH_Cont_Par_2
# Rank 10: Score 0.3639 | 7Networks_LH_Vis_27 <-> 7Networks_RH_DorsAttn_FEF_3

# %% [markdown]
# # MLP for Mult

# %%
X_avg_m, y_avg_m = get_mult_data()
all_test_labels_m, all_test_probs_m, all_test_preds_m, feature_weights_m, selected_indices_m = train_mlp_model(X_avg_m, y_avg_m)
# Out:
# Starting Stratified 5-Fold CV with LASSO regularization...
# Fold 1 complete.
# Fold 2 complete.
# Fold 3 complete.
# Fold 4 complete.
# Fold 5 complete.
#
# Final Stratified K-Fold Accuracy: 90.00%

# %%
plt_roc_curve(all_test_labels_m, all_test_probs_m)

# %%
plt_confusion_matrix(all_test_labels_m, all_test_preds_m)
# Out:
# Detailed Classification Report:
#                           precision    recall  f1-score   support
#
#      Typical Development       1.00      0.80      0.89        15
# Math Learning Difficulty       0.83      1.00      0.91        15
#
#                 accuracy                           0.90        30
#                macro avg       0.92      0.90      0.90        30
#             weighted avg       0.92      0.90      0.90        30

# %%
get_winning_conn(feature_weights_m, selected_indices_m)
# Out:
# 100 connections survived.

# %%
mult_top_10_conn = get_top_10_conn(feature_weights_m, selected_indices_m)
# Out:
# --- Top 10 Connectivity Fingerprints ---
# [fetch_atlas_schaefer_2018] Dataset found in /Users/jchong058/nilearn_data/schaefer_2018
# Rank 1: Score 2.3119 | 7Networks_RH_SomMot_38 <-> 7Networks_RH_Cont_PFCl_8
# Rank 2: Score 1.1638 | 7Networks_LH_DorsAttn_Post_1 <-> 7Networks_RH_Vis_11
# Rank 3: Score 0.7607 | 7Networks_RH_Vis_26 <-> 7Networks_RH_DorsAttn_Post_13
# Rank 4: Score 0.7269 | 7Networks_LH_Cont_PFCl_5 <-> 7Networks_RH_Limbic_TempPole_5
# Rank 5: Score 0.7098 | 7Networks_LH_Limbic_TempPole_2 <-> 7Networks_RH_SomMot_35
# Rank 6: Score 0.6254 | 7Networks_RH_Vis_26 <-> 7Networks_RH_DorsAttn_Post_9
# Rank 7: Score 0.5825 | 7Networks_LH_SalVentAttn_Med_4 <-> 7Networks_RH_Default_Temp_2
# Rank 8: Score 0.3290 | 7Networks_LH_Default_Temp_8 <-> 7Networks_RH_Cont_pCun_2
# Rank 9: Score 0.3136 | 7Networks_RH_SomMot_25 <-> 7Networks_RH_DorsAttn_Post_13
# Rank 10: Score 0.3127 | 7Networks_RH_Vis_17 <-> 7Networks_RH_Default_PFCdPFCm_12

# %% [markdown]
# # MLP for Sub

# %%
X_avg_s, y_avg_s = get_sub_data()
all_test_labels_s, all_test_probs_s, all_test_preds_s, feature_weights_s, selected_indices_s = train_mlp_model(X_avg_s, y_avg_s)
# Out:
# Starting Stratified 5-Fold CV with LASSO regularization...
# Fold 1 complete.
# Fold 2 complete.
# Fold 3 complete.
# Fold 4 complete.
# Fold 5 complete.
#
# Final Stratified K-Fold Accuracy: 86.67%

# %%
plt_roc_curve(all_test_labels_s, all_test_probs_s)

# %%
plt_confusion_matrix(all_test_labels_s, all_test_preds_s)
# Out:
# Detailed Classification Report:
#                           precision    recall  f1-score   support
#
#      Typical Development       0.87      0.87      0.87        15
# Math Learning Difficulty       0.87      0.87      0.87        15
#
#                 accuracy                           0.87        30
#                macro avg       0.87      0.87      0.87        30
#             weighted avg       0.87      0.87      0.87        30

# %%
get_winning_conn(feature_weights_s, selected_indices_s)
# Out:
# 100 connections survived.

# %%
sub_top_10_conn = get_top_10_conn(feature_weights_s, selected_indices_s)
# Out:
# --- Top 10 Connectivity Fingerprints ---
# [fetch_atlas_schaefer_2018] Dataset found in /Users/jchong058/nilearn_data/schaefer_2018
# Rank 1: Score 1.8880 | 7Networks_LH_Vis_16 <-> 7Networks_LH_DorsAttn_Post_14
# Rank 2: Score 1.4269 | 7Networks_LH_SomMot_5 <-> 7Networks_RH_Cont_PFCl_5
# Rank 3: Score 1.3267 | 7Networks_LH_SomMot_29 <-> 7Networks_LH_Default_Par_2
# Rank 4: Score 1.2185 | 7Networks_LH_Default_Par_1 <-> 7Networks_RH_Vis_2
# Rank 5: Score 1.1521 | 7Networks_LH_Vis_20 <-> 7Networks_RH_SomMot_32
# Rank 6: Score 0.8584 | 7Networks_LH_Default_Temp_8 <-> 7Networks_RH_Default_PFCdPFCm_6
# Rank 7: Score 0.6393 | 7Networks_LH_Vis_25 <-> 7Networks_RH_Cont_Par_2
# Rank 8: Score 0.4046 | 7Networks_LH_Vis_20 <-> 7Networks_RH_Cont_PFCl_4
# Rank 9: Score 0.3334 | 7Networks_LH_SomMot_32 <-> 7Networks_RH_Vis_19
# Rank 10: Score 0.2687 | 7Networks_RH_SomMot_38 <-> 7Networks_RH_Cont_Cing_2

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
import torch
import numpy as np

def train_mlp_with_gridsearch(X_avg, y_avg):
    """Grid search for MLP hyperparameters using ROC-AUC."""
    
    # Feature selection (same as before)
    from sklearn.feature_selection import SelectKBest, f_classif
    from sklearn.preprocessing import StandardScaler
    
    selector = SelectKBest(score_func=f_classif, k=100)
    X_reduced = selector.fit_transform(X_avg, y_avg)
    selected_indices = selector.get_support(indices=True)
    
    scaler = StandardScaler()
    X_final = scaler.fit_transform(X_reduced)
    
    # Hyperparameter grid
    param_grid = {
        'hidden_dim': [16, 32, 64],
        'l1_lambda': [0.001, 0.005, 0.01, 0.05],
        'lr': [0.001, 0.01, 0.1],
        'epochs': [100, 200]
    }
    
    best_auc = 0
    best_params = {}
    results = []
    
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    
    print(f"Starting Grid Search with {len(param_grid['hidden_dim']) * len(param_grid['l1_lambda']) * len(param_grid['lr']) * len(param_grid['epochs'])} combinations...\n")
    
    combo_count = 0
    for hidden_dim in param_grid['hidden_dim']:
        for l1_lambda in param_grid['l1_lambda']:
            for lr in param_grid['lr']:
                for epochs in param_grid['epochs']:
                    combo_count += 1
                    print(f"[{combo_count}] Testing: hidden={hidden_dim}, l1={l1_lambda}, lr={lr}, epochs={epochs}")
                    
                    fold_aucs = []
                    
                    for fold, (train_idx, test_idx) in enumerate(skf.split(X_final, y_avg)):
                        X_train, X_test = X_final[train_idx], X_final[test_idx]
                        y_train, y_test = y_avg[train_idx], y_avg[test_idx]
                        
                        # Convert to tensors
                        X_train_t = torch.tensor(X_train, dtype=torch.float32)
                        y_train_t = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
                        X_test_t = torch.tensor(X_test, dtype=torch.float32)
                        
                        # Build dynamic model with hidden_dim
                        model = torch.nn.Sequential(
                            torch.nn.Linear(100, hidden_dim),
                            torch.nn.ReLU(),
                            torch.nn.Linear(hidden_dim, 1),
                            torch.nn.Sigmoid()
                        )
                        
                        criterion = torch.nn.BCELoss()
                        optimizer = torch.optim.Adam(model.parameters(), lr=lr)
                        
                        # Training loop
                        model.train()
                        for epoch in range(epochs):
                            optimizer.zero_grad()
                            outputs = model(X_train_t)
                            bce_loss = criterion(outputs, y_train_t)
                            
                            # Improved LASSO: apply to all weights
                            l1_penalty = sum(torch.norm(p, 1) for p in model.parameters() if p.dim() > 1)
                            total_loss = bce_loss + (l1_lambda * l1_penalty)
                            
                            total_loss.backward()
                            optimizer.step()
                        
                        # Evaluate on test fold
                        model.eval()
                        with torch.no_grad():
                            test_probs = model(X_test_t).numpy().flatten()
                        
                        # Calculate ROC-AUC
                        auc = roc_auc_score(y_test, test_probs)
                        fold_aucs.append(auc)
                    
                    mean_auc = np.mean(fold_aucs)
                    std_auc = np.std(fold_aucs)
                    
                    results.append({
                        'hidden_dim': hidden_dim,
                        'l1_lambda': l1_lambda,
                        'lr': lr,
                        'epochs': epochs,
                        'mean_auc': mean_auc,
                        'std_auc': std_auc
                    })
                    
                    print(f"  → Mean AUC: {mean_auc:.4f} ± {std_auc:.4f}\n")
                    
                    if mean_auc > best_auc:
                        best_auc = mean_auc
                        best_params = {
                            'hidden_dim': hidden_dim,
                            'l1_lambda': l1_lambda,
                            'lr': lr,
                            'epochs': epochs
                        }
    
    print(f"\n{'='*70}")
    print(f"Best Parameters: {best_params}")
    print(f"Best Mean AUC: {best_auc:.4f}")
    print(f"{'='*70}\n")
    
    return best_params, results, selected_indices, scaler

# Run grid search
best_params, grid_results, selected_indices, scaler = train_mlp_with_gridsearch(X_avg, y_avg)

# Convert results to DataFrame for analysis
# import pandas as pd
# df_results = pd.DataFrame(grid_results)
# df_results.to_csv('mlp_gridsearch_results.csv', index=False)
# print("✅ Grid search results saved to mlp_gridsearch_results.csv")
# Out:
# Starting Grid Search with 72 combinations...
#
# [1] Testing: hidden=16, l1=0.001, lr=0.001, epochs=100
#   → Mean AUC: 0.9556 ± 0.0544
#
# [2] Testing: hidden=16, l1=0.001, lr=0.001, epochs=200
#   → Mean AUC: 0.9556 ± 0.0544
#
# [3] Testing: hidden=16, l1=0.001, lr=0.01, epochs=100
#   → Mean AUC: 0.9778 ± 0.0444
#
# [4] Testing: hidden=16, l1=0.001, lr=0.01, epochs=200
#   → Mean AUC: 0.9778 ± 0.0444
#
# [5] Testing: hidden=16, l1=0.001, lr=0.1, epochs=100
#   → Mean AUC: 0.9333 ± 0.0889
#
# [6] Testing: hidden=16, l1=0.001, lr=0.1, epochs=200
#   → Mean AUC: 0.9333 ± 0.0889
#
# [7] Testing: hidden=16, l1=0.005, lr=0.001, epochs=100
#   → Mean AUC: 0.9333 ± 0.0889
#
# [8] Testing: hidden=16, l1=0.005, lr=0.001, epochs=200
#   → Mean AUC: 0.9333 ± 0.0889
#
# [9] Testing: hidden=16, l1=0.005, lr=0.01, epochs=100
#   → Mean AUC: 0.9333 ± 0.0889
#
# [10] Testing: hidden=16, l1=0.005, lr=0.01, epochs=200
#   → Mean AUC: 0.9333 ± 0.0889
#
# ...

# %%
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

def train_final_mlp_model(X_avg, y_avg, best_params):
    """Train final MLP model using best hyperparameters from grid search."""
    
    # Feature selection
    selector = SelectKBest(score_func=f_classif, k=100)
    X_reduced = selector.fit_transform(X_avg, y_avg)
    selected_indices = selector.get_support(indices=True)

    # Scale the data
    scaler = StandardScaler()
    X_final = scaler.fit_transform(X_reduced)

    all_test_preds = []
    all_test_labels = []
    all_test_probs = []

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    print(f"Training Final MLP Model with Best Parameters:")
    print(f"  hidden_dim={best_params['hidden_dim']}")
    print(f"  l1_lambda={best_params['l1_lambda']}")
    print(f"  lr={best_params['lr']}")
    print(f"  epochs={best_params['epochs']}\n")

    # Train on each fold
    for fold, (train_idx, test_idx) in enumerate(skf.split(X_final, y_avg)):
        X_train, X_test = X_final[train_idx], X_final[test_idx]
        y_train, y_test = y_avg[train_idx], y_avg[test_idx]

        # Convert to tensors
        X_train_t = torch.tensor(X_train, dtype=torch.float32)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
        X_test_t = torch.tensor(X_test, dtype=torch.float32)

        # Build model with best params
        model = torch.nn.Sequential(
            torch.nn.Linear(100, best_params['hidden_dim']),
            torch.nn.ReLU(),
            torch.nn.Linear(best_params['hidden_dim'], 1),
            torch.nn.Sigmoid()
        )

        criterion = torch.nn.BCELoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=best_params['lr'])

        # Training loop
        model.train()
        for epoch in range(best_params['epochs']):
            optimizer.zero_grad()
            outputs = model(X_train_t)
            bce_loss = criterion(outputs, y_train_t)
            
            # L1 penalty on all weight matrices
            l1_penalty = sum(torch.norm(p, 1) for p in model.parameters() if p.dim() > 1)
            total_loss = bce_loss + (best_params['l1_lambda'] * l1_penalty)
            
            total_loss.backward()
            optimizer.step()

        # Evaluate on test fold
        model.eval()
        with torch.no_grad():
            test_probs_t = model(X_test_t)
            preds = (test_probs_t > 0.5).float().numpy().flatten()
            
            all_test_probs.extend(test_probs_t.numpy().flatten())
            all_test_preds.extend(preds)
            all_test_labels.extend(y_test)
        
        print(f"Fold {fold+1} complete.")

    # Convert to numpy arrays
    all_test_labels = np.array(all_test_labels)
    all_test_preds = np.array(all_test_preds)
    all_test_probs = np.array(all_test_probs)

    # Final evaluation
    final_acc = accuracy_score(all_test_labels, all_test_preds)
    final_auc = roc_auc_score(all_test_labels, all_test_probs)

    print(f"\n{'='*70}")
    print(f"Final MLP Model Performance (5-Fold CV)")
    print(f"{'='*70}")
    print(f"Accuracy: {final_acc * 100:.2f}%")
    print(f"ROC-AUC: {final_auc:.4f}\n")
    print(classification_report(all_test_labels, all_test_preds, target_names=['TD', 'MLD']))

    # Confusion Matrix
    plt.figure(figsize=(6, 5))
    cm = confusion_matrix(all_test_labels, all_test_preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['TD', 'MLD'], yticklabels=['TD', 'MLD'],
                cbar_kws={'label': 'Count'})
    plt.title("Final MLP - Confusion Matrix (Best Hyperparameters)")
    plt.ylabel("True Label")
    plt.xlabel("Predicted Label")
    plt.tight_layout()
    plt.show()

    # ROC Curve
    from sklearn.metrics import roc_curve, auc
    fpr, tpr, _ = roc_curve(all_test_labels, all_test_probs)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(7, 7))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.4f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve - Final MLP Model')
    plt.legend(loc="lower right")
    plt.grid(alpha=0.3)
    plt.show()

    return all_test_labels, all_test_probs, all_test_preds, selected_indices

# Train final model
best_params = {
    'hidden_dim': 16,
    'l1_lambda': 0.001,
    'lr': 0.01,
    'epochs': 100
}

y_labels_final, y_probs_final, y_preds_final, selected_indices_final = train_final_mlp_model(X_avg, y_avg, best_params)

# Save results to CSV
# mlp_probs_flat = np.array(y_probs_final).flatten()

# df_mlp_final = pd.DataFrame({
#     'true_label': y_labels_final,
#     'mlp_prob': mlp_probs_flat,
#     'mlp_pred': y_preds_final
# })
# df_mlp_final.to_csv('preds/mlp_final_results.csv', index=False)
# print("\n✅ Final MLP results saved to preds/mlp_final_results.csv")
# Out:
# Training Final MLP Model with Best Parameters:
#   hidden_dim=16
#   l1_lambda=0.001
#   lr=0.01
#   epochs=100
#
# Fold 1 complete.
# Fold 2 complete.
# Fold 3 complete.
# Fold 4 complete.
# Fold 5 complete.
#
# ...
# Final MLP Model Performance (5-Fold CV)
# ...
# Accuracy: 90.00%
# ROC-AUC: 0.9867
#
#               precision    recall  f1-score   support
#
#           TD       1.00      0.80      0.89        15
#          MLD       0.83      1.00      0.91        15
#
#     accuracy                           0.90        30
#    macro avg       0.92      0.90      0.90        30
# weighted avg       0.92      0.90      0.90        30

# %%
all_top_10_conn = get_top_10_conn(feature_weights, selected_indices)
# Out:
# --- Top 10 Connectivity Fingerprints ---
# [fetch_atlas_schaefer_2018] Dataset found in /Users/jchong058/nilearn_data/schaefer_2018
# Rank 1: Score 1.5622 | 7Networks_RH_SomMot_38 <-> 7Networks_RH_Cont_PFCl_8
# Rank 2: Score 1.4894 | 7Networks_LH_DorsAttn_Post_6 <-> 7Networks_LH_Default_pCunPCC_3
# Rank 3: Score 1.2529 | 7Networks_RH_SomMot_17 <-> 7Networks_RH_DorsAttn_FEF_1
# Rank 4: Score 0.9369 | 7Networks_LH_Vis_16 <-> 7Networks_LH_DorsAttn_Post_14
# Rank 5: Score 0.8473 | 7Networks_LH_Default_Par_1 <-> 7Networks_RH_Vis_2
# Rank 6: Score 0.8130 | 7Networks_LH_Cont_PFCl_5 <-> 7Networks_RH_Limbic_TempPole_5
# Rank 7: Score 0.6419 | 7Networks_RH_Vis_26 <-> 7Networks_RH_DorsAttn_Post_9
# Rank 8: Score 0.6220 | 7Networks_LH_Limbic_TempPole_5 <-> 7Networks_LH_Cont_PFCl_1
# Rank 9: Score 0.3802 | 7Networks_LH_Vis_25 <-> 7Networks_RH_Cont_Par_2
# Rank 10: Score 0.3639 | 7Networks_LH_Vis_27 <-> 7Networks_RH_DorsAttn_FEF_3

# %%
def get_top_10_conn_final(X_avg, y_avg, best_params):
    """Get top 10 connections from the final trained MLP model."""
    from sklearn.feature_selection import SelectKBest, f_classif
    from sklearn.preprocessing import StandardScaler
    
    # Feature selection
    selector = SelectKBest(score_func=f_classif, k=100)
    X_reduced = selector.fit_transform(X_avg, y_avg)
    selected_indices = selector.get_support(indices=True)

    # Scale the data
    scaler = StandardScaler()
    X_final = scaler.fit_transform(X_reduced)

    # Train final model on all data to get feature weights
    X_train_t = torch.tensor(X_final, dtype=torch.float32)
    y_train_t = torch.tensor(y_avg, dtype=torch.float32).view(-1, 1)

    # Build model with best params
    model = torch.nn.Sequential(
        torch.nn.Linear(100, best_params['hidden_dim']),
        torch.nn.ReLU(),
        torch.nn.Linear(best_params['hidden_dim'], 1),
        torch.nn.Sigmoid()
    )

    criterion = torch.nn.BCELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=best_params['lr'])

    # Training loop
    model.train()
    for epoch in range(best_params['epochs']):
        optimizer.zero_grad()
        outputs = model(X_train_t)
        bce_loss = criterion(outputs, y_train_t)
        
        # L1 penalty
        l1_penalty = sum(torch.norm(p, 1) for p in model.parameters() if p.dim() > 1)
        total_loss = bce_loss + (best_params['l1_lambda'] * l1_penalty)
        
        total_loss.backward()
        optimizer.step()

    # Get feature weights from first layer
    model.eval()
    feature_weights = torch.abs(model[0].weight).sum(dim=0).detach().numpy()
    
    # Get top 10
    top_10_meta_indices = np.argsort(feature_weights)[-10:][::-1]
    top_10_raw_indices = selected_indices[top_10_meta_indices]

    # Print results
    print(f"\n{'='*80}")
    print(f"Top 10 Brain Connectivity Fingerprints (Final MLP Model)")
    print(f"{'='*80}\n")
    
    top_connections_info = []
    labels = get_labels()
    
    for i, raw_idx in enumerate(top_10_raw_indices):
        roi_a_idx, roi_b_idx = get_roi_names(raw_idx)
        
        label_a = labels[roi_a_idx]
        label_b = labels[roi_b_idx]
        score = feature_weights[top_10_meta_indices[i]]
        
        print(f"Rank {i+1:2d}: Score {score:.6f} | {label_a} <-> {label_b}")
        
        top_connections_info.append({
            'rank': i+1,
            'score': score,
            'roi_a': label_a,
            'roi_b': label_b,
            'roi_a_idx': roi_a_idx,
            'roi_b_idx': roi_b_idx
        })
    
    print(f"\n{'='*80}\n")
    
    return top_connections_info

# Run after final model training
best_params = {
    'hidden_dim': 16,
    'l1_lambda': 0.001,
    'lr': 0.01,
    'epochs': 100
}

top_10_final = get_top_10_conn_final(X_avg, y_avg, best_params)
# Out:
# ...
# Top 10 Brain Connectivity Fingerprints (Final MLP Model)
# ...
#
# [fetch_atlas_schaefer_2018] Dataset found in /Users/jchong058/nilearn_data/schaefer_2018
# Rank  1: Score 2.246982 | 7Networks_RH_SomMot_17 <-> 7Networks_RH_DorsAttn_FEF_1
# Rank  2: Score 1.775071 | 7Networks_RH_SomMot_38 <-> 7Networks_RH_Cont_PFCl_8
# Rank  3: Score 1.327344 | 7Networks_LH_Cont_PFCl_5 <-> 7Networks_RH_Limbic_TempPole_5
# Rank  4: Score 1.280493 | 7Networks_LH_Vis_16 <-> 7Networks_LH_DorsAttn_Post_14
# Rank  5: Score 1.156363 | 7Networks_LH_Limbic_TempPole_5 <-> 7Networks_LH_Cont_PFCl_1
# Rank  6: Score 1.107511 | 7Networks_LH_Vis_27 <-> 7Networks_RH_DorsAttn_FEF_3
# Rank  7: Score 1.067587 | 7Networks_RH_SomMot_37 <-> 7Networks_RH_Limbic_OFC_5
# Rank  8: Score 1.040609 | 7Networks_RH_SomMot_25 <-> 7Networks_RH_DorsAttn_PrCv_1
# Rank  9: Score 0.944882 | 7Networks_RH_Vis_26 <-> 7Networks_RH_DorsAttn_Post_9
# Rank 10: Score 0.914082 | 7Networks_LH_SomMot_16 <-> 7Networks_LH_Cont_PFCl_5
#
# ...

# %%
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import torch

def train_final_mlp_model(X_avg, y_avg, best_params):
    """Train final MLP model using best hyperparameters from grid search."""
    
    all_test_preds = []
    all_test_labels = []
    all_test_probs = []
    all_selected_indices = [] # Changed: List to hold the selected features for each fold

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    print(f"Training Final MLP Model with Best Parameters:")
    print(f"  hidden_dim={best_params['hidden_dim']}")
    print(f"  l1_lambda={best_params['l1_lambda']}")
    print(f"  lr={best_params['lr']}")
    print(f"  epochs={best_params['epochs']}\n")

    # Train on each fold using the raw, unscaled X_avg
    for fold, (train_idx, test_idx) in enumerate(skf.split(X_avg, y_avg)):
        
        # 1. Split the raw data FIRST
        X_train_raw, X_test_raw = X_avg[train_idx], X_avg[test_idx]
        y_train, y_test = y_avg[train_idx], y_avg[test_idx]

        # 2. Feature Selection: Fit ONLY on training data
        selector = SelectKBest(score_func=f_classif, k=100)
        X_train_reduced = selector.fit_transform(X_train_raw, y_train)
        X_test_reduced = selector.transform(X_test_raw) # Transform test data based on train selection
        
        # Store selected indices for this specific fold
        all_selected_indices.append(selector.get_support(indices=True))

        # 3. Scale the Data: Fit ONLY on training data
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train_reduced)
        X_test_scaled = scaler.transform(X_test_reduced) # Transform test data based on train scaling

        # 4. Convert to tensors
        X_train_t = torch.tensor(X_train_scaled, dtype=torch.float32)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
        X_test_t = torch.tensor(X_test_scaled, dtype=torch.float32)

        # Build model with best params
        model = torch.nn.Sequential(
            torch.nn.Linear(100, best_params['hidden_dim']),
            torch.nn.ReLU(),
            torch.nn.Linear(best_params['hidden_dim'], 1),
            torch.nn.Sigmoid()
        )

        criterion = torch.nn.BCELoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=best_params['lr'])

        # Training loop
        model.train()
        for epoch in range(best_params['epochs']):
            optimizer.zero_grad()
            outputs = model(X_train_t)
            bce_loss = criterion(outputs, y_train_t)
            
            # L1 penalty on all weight matrices
            l1_penalty = sum(torch.norm(p, 1) for p in model.parameters() if p.dim() > 1)
            total_loss = bce_loss + (best_params['l1_lambda'] * l1_penalty)
            
            total_loss.backward()
            optimizer.step()

        # Evaluate on test fold
        model.eval()
        with torch.no_grad():
            test_probs_t = model(X_test_t)
            preds = (test_probs_t > 0.5).float().numpy().flatten()
            
            all_test_probs.extend(test_probs_t.numpy().flatten())
            all_test_preds.extend(preds)
            all_test_labels.extend(y_test)
        
        print(f"Fold {fold+1} complete.")

    # Convert to numpy arrays
    all_test_labels = np.array(all_test_labels)
    all_test_preds = np.array(all_test_preds)
    all_test_probs = np.array(all_test_probs)

    # Final evaluation
    final_acc = accuracy_score(all_test_labels, all_test_preds)
    final_auc = roc_auc_score(all_test_labels, all_test_probs)

    print(f"\n{'='*70}")
    print(f"Final MLP Model Performance (5-Fold CV)")
    print(f"{'='*70}")
    print(f"Accuracy: {final_acc * 100:.2f}%")
    print(f"ROC-AUC: {final_auc:.4f}\n")
    print(classification_report(all_test_labels, all_test_preds, target_names=['TD', 'MLD']))

    # Confusion Matrix
    plt.figure(figsize=(6, 5))
    cm = confusion_matrix(all_test_labels, all_test_preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['TD', 'MLD'], yticklabels=['TD', 'MLD'],
                cbar_kws={'label': 'Count'})
    plt.title("Final MLP - Confusion Matrix (Best Hyperparameters)")
    plt.ylabel("True Label")
    plt.xlabel("Predicted Label")
    plt.tight_layout()
    plt.show()

    # ROC Curve
    from sklearn.metrics import roc_curve, auc
    fpr, tpr, _ = roc_curve(all_test_labels, all_test_probs)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(7, 7))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.4f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve - Final MLP Model')
    plt.legend(loc="lower right")
    plt.grid(alpha=0.3)
    plt.show()

    return all_test_labels, all_test_probs, all_test_preds, all_selected_indices

# Train final model
best_params = {
    'hidden_dim': 4,
    'l1_lambda': 0.001,
    'lr': 0.01,
    'epochs': 100
}

y_labels_final, y_probs_final, y_preds_final, all_selected_indices = train_final_mlp_model(X_avg, y_avg, best_params)
# Out:
# Training Final MLP Model with Best Parameters:
#   hidden_dim=4
#   l1_lambda=0.001
#   lr=0.01
#   epochs=100
#
# Fold 1 complete.
# Fold 2 complete.
# Fold 3 complete.
# Fold 4 complete.
# Fold 5 complete.
#
# ...
# Final MLP Model Performance (5-Fold CV)
# ...
# Accuracy: 60.00%
# ROC-AUC: 0.5511
#
#               precision    recall  f1-score   support
#
#           TD       0.59      0.67      0.62        15
#          MLD       0.62      0.53      0.57        15
#
#     accuracy                           0.60        30
#    macro avg       0.60      0.60      0.60        30
# weighted avg       0.60      0.60      0.60        30

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold, cross_val_predict
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Assuming helper_lin is your local module
from helper_lin import get_all_data, get_labels

# 1. Load Data
labels = get_labels()
X_avg, y_avg = get_all_data()

# 2. Define Best Parameters from Grid Search
best_params = {
    'C': 1,
    'kernel': 'rbf',
    'gamma': 0.001
}

# 3. Create the Pipeline
final_svm_pipeline = Pipeline([
    ('feature_selection', SelectKBest(f_classif, k=100)),
    ('scaler', StandardScaler()),
    ('svm', SVC(
        C=best_params['C'],
        kernel=best_params['kernel'],
        gamma=best_params['gamma'],
        probability=True,
        random_state=42
    ))
])

print(f"{'='*70}")
print(f"PHASE 1: Valid Model Evaluation (5-Fold Cross-Validation)")
print(f"{'='*70}")

# 4. Generate Valid Out-of-Fold Predictions
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

y_pred_final = cross_val_predict(final_svm_pipeline, X_avg, y_avg, cv=skf, method='predict')
y_probs_final = cross_val_predict(final_svm_pipeline, X_avg, y_avg, cv=skf, method='predict_proba')

# 5. Evaluate Valid Predictions
acc_final = accuracy_score(y_avg, y_pred_final)
print(f"True Cross-Validated Accuracy: {acc_final * 100:.2f}%\n")
print(classification_report(y_avg, y_pred_final, target_names=['TD', 'MLD']))

# 6. Plot Confusion Matrix
plt.figure(figsize=(6, 5))
cm = confusion_matrix(y_avg, y_pred_final)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['TD', 'MLD'], 
            yticklabels=['TD', 'MLD'],
            cbar_kws={'label': 'Count'})
plt.title("Final SVM - Confusion Matrix (Out-of-Fold Predictions)")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.tight_layout()
plt.show()

# 7. Save Valid Predictions to CSV
svm_probs_class1 = [p[1] for p in y_probs_final]

df_svm_final = pd.DataFrame({
    'true_label': y_avg,
    'svm_prob': svm_probs_class1,
    'svm_pred': y_pred_final
})
df_svm_final.to_csv('preds/svm_final_results.csv', index=False)
print("✅ Valid Out-of-Fold Results saved to preds/svm_final_results.csv\n")


print(f"{'='*70}")
print(f"PHASE 2: Feature Importance Extraction (Trained on All Data)")
print(f"{'='*70}")

# 8. Train one final time on ALL data to find the most globally important features
final_svm_pipeline.fit(X_avg, y_avg)

# 9. Extract features from the SelectKBest step
selector = final_svm_pipeline.named_steps['feature_selection']
support = selector.get_support()
feature_indices = np.where(support)[0]
scores = selector.scores_

# 10. Map to ROI pairs
roi_indices = np.triu_indices(400, k=1)
roi_pairs = list(zip(roi_indices[0], roi_indices[1]))

print(f"Top 10 Most Important Brain Connections:")
print(f"{'Brain Connection':<55} | {'ANOVA F-Score':<10}")
print("-" * 70)

# Get indices of top 10 scores from the SELECTED features only
top_10_indices = np.argsort(scores[feature_indices])[::-1][:10]

for i, idx in enumerate(top_10_indices):
    feat_idx = feature_indices[idx]  # Get original feature index (0 to ~79800)
    roi_a, roi_b = roi_pairs[feat_idx]
    
    name_a = labels[roi_a] 
    name_b = labels[roi_b]
    
    connection_str = f"{name_a} <-> {name_b}"
    print(f"{connection_str:<55} | {scores[feature_indices[idx]]:.4f}")
# Out:
# [fetch_atlas_schaefer_2018] Dataset found in /Users/jchong058/nilearn_data/schaefer_2018
# ...
# PHASE 1: Valid Model Evaluation (5-Fold Cross-Validation)
# ...
# True Cross-Validated Accuracy: 56.67%
#
#               precision    recall  f1-score   support
#
#           TD       0.57      0.53      0.55        15
#          MLD       0.56      0.60      0.58        15
#
#     accuracy                           0.57        30
#    macro avg       0.57      0.57      0.57        30
# weighted avg       0.57      0.57      0.57        30
# ✅ Valid Out-of-Fold Results saved to preds/svm_final_results.csv
#
# ...
# PHASE 2: Feature Importance Extraction (Trained on All Data)
# ...
# Top 10 Most Important Brain Connections:
# Brain Connection                                        | ANOVA F-Score
# ----------------------------------------------------------------------
# 7Networks_LH_SomMot_16 <-> 7Networks_LH_Cont_PFCl_1     | 21.0363
# 7Networks_RH_Vis_11 <-> 7Networks_RH_Default_PFCdPFCm_12 | 20.8872
# ...

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report

def extract_single_fold_diagnostics(X_avg, y_avg, best_params):
    """
    Runs a single fold of the MLP to extract training loss curves 
    and compare Train vs Test performance, as requested for data leakage/overfitting diagnosis.
    """
    print("Extracting Diagnostics for Fold 1...\n")
    
    # Use the same split logic
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    
    # We only want ONE fold, so we'll break after the first iteration
    for fold, (train_idx, test_idx) in enumerate(skf.split(X_avg, y_avg)):
        
        # 1. Split Raw Data
        X_train_raw, X_test_raw = X_avg[train_idx], X_avg[test_idx]
        y_train, y_test = y_avg[train_idx], y_avg[test_idx]

        # 2. Preprocess (Strictly fitted on training data to prevent leakage)
        selector = SelectKBest(score_func=f_classif, k=100)
        X_train_reduced = selector.fit_transform(X_train_raw, y_train)
        X_test_reduced = selector.transform(X_test_raw) 
        
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train_reduced)
        X_test_scaled = scaler.transform(X_test_reduced) 

        # 3. Convert to Tensors
        X_train_t = torch.tensor(X_train_scaled, dtype=torch.float32)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
        X_test_t = torch.tensor(X_test_scaled, dtype=torch.float32)
        y_test_t = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

        # 4. Build Model
        model = torch.nn.Sequential(
            torch.nn.Linear(100, best_params['hidden_dim']),
            torch.nn.ReLU(),
            torch.nn.Linear(best_params['hidden_dim'], 1),
            torch.nn.Sigmoid()
        )

        criterion = torch.nn.BCELoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=best_params['lr'])

        # --- NEW: Track loss across epochs ---
        epoch_losses = []

        # 5. Training Loop
        model.train()
        for epoch in range(best_params['epochs']):
            optimizer.zero_grad()
            outputs = model(X_train_t)
            bce_loss = criterion(outputs, y_train_t)
            
            l1_penalty = sum(torch.norm(p, 1) for p in model.parameters() if p.dim() > 1)
            total_loss = bce_loss + (best_params['l1_lambda'] * l1_penalty)
            
            total_loss.backward()
            optimizer.step()
            
            # Save the loss value for plotting
            epoch_losses.append(total_loss.item())

        # 6. Evaluation on BOTH Train and Test sets
        model.eval()
        with torch.no_grad():
            # Evaluate Training Set
            train_probs = model(X_train_t).numpy().flatten()
            train_preds = (train_probs > 0.5).astype(int)
            train_acc = accuracy_score(y_train, train_preds)
            
            # Attempt AUC, but handle case where fold might only have one class (unlikely with Stratified, but safe)
            try:
                train_auc = roc_auc_score(y_train, train_probs)
            except ValueError:
                train_auc = float('nan')

            # Evaluate Testing Set
            test_probs = model(X_test_t).numpy().flatten()
            test_preds = (test_probs > 0.5).astype(int)
            test_acc = accuracy_score(y_test, test_preds)
            
            try:
                test_auc = roc_auc_score(y_test, test_probs)
            except ValueError:
                test_auc = float('nan')

        # --- 7. Print Results ---
        print(f"{'='*50}")
        print(f"PERFORMANCE REPORT: FOLD 1")
        print(f"{'='*50}")
        print(f"TRAINING SET:")
        print(f"  Accuracy: {train_acc*100:.2f}%")
        print(f"  AUC:      {train_auc:.4f}")
        print("-" * 50)
        print(f"TESTING SET:")
        print(f"  Accuracy: {test_acc*100:.2f}%")
        print(f"  AUC:      {test_auc:.4f}")
        print(f"{'='*50}\n")
        
        # --- 8. Plot Loss Curve ---
        plt.figure(figsize=(8, 5))
        plt.plot(range(1, best_params['epochs'] + 1), epoch_losses, color='blue', linewidth=2)
        plt.title('Training Loss Trajectory (Fold 1)', fontsize=14)
        plt.xlabel('Epoch', fontsize=12)
        plt.ylabel('Total Loss (BCE + L1)', fontsize=12)
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        
        # Save the plot so you can easily send it to them
        plt.savefig("fold1_loss_curve.png", dpi=300)
        print("✅ Loss curve saved as 'fold1_loss_curve.png'")
        plt.show()

        # Stop after Fold 1
        break

# Run the function
best_params = {
    'hidden_dim': 16,
    'l1_lambda': 0.001,
    'lr': 0.01,
    'epochs': 100
}

# Assuming X_avg and y_avg are already loaded in your environment
extract_single_fold_diagnostics(X_avg, y_avg, best_params)
# Out:
# Extracting Diagnostics for Fold 1...
#
# ...
# PERFORMANCE REPORT: FOLD 1
# ...
# TRAINING SET:
#   Accuracy: 100.00%
#   AUC:      1.0000
# --------------------------------------------------
# TESTING SET:
#   Accuracy: 50.00%
#   AUC:      0.4444
# ...
#
# ✅ Loss curve saved as 'fold1_loss_curve.png'

# %%
import torch
import numpy as np
import pandas as pd
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold, ParameterGrid
from sklearn.metrics import accuracy_score, roc_auc_score

def run_anti_overfitting_grid_search(X_avg, y_avg):
    print("Starting Aggressive Anti-Overfitting Grid Search...")
    
    # 1. Define the restricted search space
    param_grid = {
        'k_features': [10, 20, 30],       # Much fewer features
        'hidden_dim': [4, 8],             # Smaller network
        'l1_lambda': [0.01, 0.05, 0.1],   # Stronger regularization
        'dropout_rate': [0.2, 0.5],       # NEW: Dropout to prevent memorization
        'lr': [0.005, 0.01],
        'epochs': [50, 100]               # Fewer epochs can also prevent overfitting
    }
    
    grid = list(ParameterGrid(param_grid))
    print(f"Total combinations to test: {len(grid)}\n")
    
    results = []
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    # 2. Iterate through all parameter combinations
    for i, params in enumerate(grid):
        
        fold_accs = []
        fold_aucs = []
        fold_train_accs = [] # Track train accuracy to monitor overfitting
        
        # 5-Fold CV for the current parameter set
        for train_idx, test_idx in skf.split(X_avg, y_avg):
            # Split Data
            X_train_raw, X_test_raw = X_avg[train_idx], X_avg[test_idx]
            y_train, y_test = y_avg[train_idx], y_avg[test_idx]

            # Preprocess (Inside loop to prevent leakage)
            selector = SelectKBest(score_func=f_classif, k=params['k_features'])
            X_train_reduced = selector.fit_transform(X_train_raw, y_train)
            X_test_reduced = selector.transform(X_test_raw)
            
            scaler = StandardScaler()
            X_train_scaled = scaler.fit_transform(X_train_reduced)
            X_test_scaled = scaler.transform(X_test_reduced)

            # Convert to Tensors
            X_train_t = torch.tensor(X_train_scaled, dtype=torch.float32)
            y_train_t = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
            X_test_t = torch.tensor(X_test_scaled, dtype=torch.float32)

            # Build Model (Notice the NEW Dropout layer)
            model = torch.nn.Sequential(
                torch.nn.Linear(params['k_features'], params['hidden_dim']),
                torch.nn.ReLU(),
                torch.nn.Dropout(p=params['dropout_rate']), 
                torch.nn.Linear(params['hidden_dim'], 1),
                torch.nn.Sigmoid()
            )

            criterion = torch.nn.BCELoss()
            optimizer = torch.optim.Adam(model.parameters(), lr=params['lr'])

            # Train Model
            model.train()
            for epoch in range(params['epochs']):
                optimizer.zero_grad()
                outputs = model(X_train_t)
                bce_loss = criterion(outputs, y_train_t)
                
                # Apply L1 penalty
                l1_penalty = sum(torch.norm(p, 1) for p in model.parameters() if p.dim() > 1)
                total_loss = bce_loss + (params['l1_lambda'] * l1_penalty)
                
                total_loss.backward()
                optimizer.step()

            # Evaluate Model
            model.eval()
            with torch.no_grad():
                # Test set evaluation
                test_probs = model(X_test_t).numpy().flatten()
                test_preds = (test_probs > 0.5).astype(int)
                fold_accs.append(accuracy_score(y_test, test_preds))
                
                try:
                    fold_aucs.append(roc_auc_score(y_test, test_probs))
                except ValueError:
                    pass # Handle edge cases in strict splits
                
                # Train set evaluation (just for monitoring)
                train_probs = model(X_train_t).numpy().flatten()
                train_preds = (train_probs > 0.5).astype(int)
                fold_train_accs.append(accuracy_score(y_train, train_preds))

        # 3. Calculate Average Metrics for this Parameter Combination
        avg_test_acc = np.mean(fold_accs)
        avg_test_auc = np.mean(fold_aucs) if fold_aucs else 0
        avg_train_acc = np.mean(fold_train_accs)
        
        # Calculate the "Overfitting Gap" (difference between train and test acc)
        overfit_gap = avg_train_acc - avg_test_acc

        results.append({
            **params,
            'Val_Accuracy': avg_test_acc,
            'Val_AUC': avg_test_auc,
            'Train_Accuracy': avg_train_acc,
            'Overfit_Gap': overfit_gap
        })

        # Print progress every 10 iterations
        if (i + 1) % 10 == 0:
            print(f"Evaluated {i + 1}/{len(grid)} combinations...")

    # 4. Sort and Display Top Results
    results_df = pd.DataFrame(results)
    
    # Sort primarily by Validation Accuracy (highest), then by Overfit Gap (lowest)
    top_results = results_df.sort_values(by=['Val_Accuracy', 'Overfit_Gap'], ascending=[False, True]).head(10)
    
    print(f"\n{'='*80}")
    print("TOP 10 HYPERPARAMETER COMBINATIONS (Sorted by Val Accuracy)")
    print(f"{'='*80}")
    print(top_results[['k_features', 'hidden_dim', 'l1_lambda', 'dropout_rate', 'epochs', 'Val_Accuracy', 'Train_Accuracy', 'Overfit_Gap']].to_string(index=False))
    
    return top_results

# Execute the Grid Search (Assuming X_avg and y_avg are loaded)
# Warning: This might take a few minutes to run
top_mlp_params = run_anti_overfitting_grid_search(X_avg, y_avg)
# Out:
# Starting Aggressive Anti-Overfitting Grid Search...
# Total combinations to test: 144
#
# Evaluated 10/144 combinations...
# Evaluated 20/144 combinations...
# Evaluated 30/144 combinations...
# Evaluated 40/144 combinations...
# Evaluated 50/144 combinations...
# Evaluated 60/144 combinations...
# Evaluated 70/144 combinations...
# Evaluated 80/144 combinations...
# Evaluated 90/144 combinations...
# Evaluated 100/144 combinations...
# Evaluated 110/144 combinations...
# Evaluated 120/144 combinations...
# Evaluated 130/144 combinations...
# Evaluated 140/144 combinations...
#
# ...
# TOP 10 HYPERPARAMETER COMBINATIONS (Sorted by Val Accuracy)
# ...
#  k_features  hidden_dim  l1_lambda  dropout_rate  epochs  Val_Accuracy  Train_Accuracy  Overfit_Gap
#          10           4       0.05           0.5     100      0.666667        0.958333     0.291667
#          10           4       0.01           0.5     100      0.666667        0.966667     0.300000
# ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix, classification_report

# Assuming helper_lin is your local module
from helper_lin import get_all_data, get_labels

def train_final_mlp_model(X_avg, y_avg, params):
    """Train the final MLP model using the optimized hyperparameters to prevent overfitting."""
    
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    
    all_test_preds = []
    all_test_labels = []
    all_test_probs = []
    all_selected_indices = []

    print(f"Training Final MLP Model with Hyperparameters:")
    print(f"  k_features:   {params['k_features']}")
    print(f"  hidden_dim:   {params['hidden_dim']}")
    print(f"  l1_lambda:    {params['l1_lambda']}")
    print(f"  dropout_rate: {params['dropout_rate']}")
    print(f"  epochs:       {params['epochs']}")
    print(f"  lr:           {params['lr']}\n")

    for fold, (train_idx, test_idx) in enumerate(skf.split(X_avg, y_avg)):
        
        # 1. Split Raw Data FIRST
        X_train_raw, X_test_raw = X_avg[train_idx], X_avg[test_idx]
        y_train, y_test = y_avg[train_idx], y_avg[test_idx]

        # 2. Feature Selection: Fit ONLY on training data
        selector = SelectKBest(score_func=f_classif, k=params['k_features'])
        X_train_reduced = selector.fit_transform(X_train_raw, y_train)
        X_test_reduced = selector.transform(X_test_raw) 
        
        # Store selected indices for this fold
        all_selected_indices.append(selector.get_support(indices=True))

        # 3. Scale the Data: Fit ONLY on training data
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train_reduced)
        X_test_scaled = scaler.transform(X_test_reduced)

        # 4. Convert to tensors
        X_train_t = torch.tensor(X_train_scaled, dtype=torch.float32)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
        X_test_t = torch.tensor(X_test_scaled, dtype=torch.float32)

        # 5. Build Model (with Dropout)
        model = nn.Sequential(
            nn.Linear(params['k_features'], params['hidden_dim']),
            nn.ReLU(),
            nn.Dropout(p=params['dropout_rate']),
            nn.Linear(params['hidden_dim'], 1),
            nn.Sigmoid()
        )

        criterion = nn.BCELoss()
        optimizer = optim.Adam(model.parameters(), lr=params['lr'])

        # 6. Training Loop
        model.train()
        for epoch in range(params['epochs']):
            optimizer.zero_grad()
            outputs = model(X_train_t)
            bce_loss = criterion(outputs, y_train_t)

            # L1 penalty
            l1_penalty = sum(torch.norm(p, 1) for p in model.parameters() if p.dim() > 1)
            total_loss = bce_loss + (params['l1_lambda'] * l1_penalty)

            total_loss.backward()
            optimizer.step()

        # 7. Evaluate on test fold
        model.eval()
        with torch.no_grad():
            test_probs = model(X_test_t).numpy().flatten()
            test_preds = (test_probs > 0.5).astype(int)

            all_test_probs.extend(test_probs)
            all_test_preds.extend(test_preds)
            all_test_labels.extend(y_test)
        
        print(f"Fold {fold+1} complete.")

    # Convert to numpy arrays
    all_test_labels = np.array(all_test_labels)
    all_test_preds = np.array(all_test_preds)
    all_test_probs = np.array(all_test_probs)

    # Final evaluation metrics
    final_acc = accuracy_score(all_test_labels, all_test_preds)
    try:
        final_auc = roc_auc_score(all_test_labels, all_test_probs)
    except ValueError:
        final_auc = float('nan') # Failsafe if a fold split misses a class

    print(f"\n{'='*70}")
    print(f"Final MLP Model Performance (5-Fold CV)")
    print(f"{'='*70}")
    print(f"True Cross-Validated Accuracy: {final_acc * 100:.2f}%")
    print(f"ROC-AUC: {final_auc:.4f}\n")
    print(classification_report(all_test_labels, all_test_preds, target_names=['TD', 'MLD']))

    # Confusion Matrix
    plt.figure(figsize=(6, 5))
    cm = confusion_matrix(all_test_labels, all_test_preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['TD', 'MLD'], yticklabels=['TD', 'MLD'],
                cbar_kws={'label': 'Count'})
    plt.title("Final MLP - Confusion Matrix")
    plt.ylabel("True Label")
    plt.xlabel("Predicted Label")
    plt.tight_layout()
    plt.show()

    # ROC Curve
    from sklearn.metrics import roc_curve, auc
    fpr, tpr, _ = roc_curve(all_test_labels, all_test_probs)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(7, 7))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.4f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve - Final MLP Model')
    plt.legend(loc="lower right")
    plt.grid(alpha=0.3)
    plt.show()

    return all_test_labels, all_test_probs, all_test_preds, all_selected_indices

# --- Execution ---
# Load your data
X_avg, y_avg = get_all_data()

# The top parameters from your grid search
# Note: The grid search output didn't list 'lr', so we're defaulting to 0.01 
# which was standard in your previous runs. You can change this to 0.005 if needed.
best_params = {
    'k_features': 10,
    'hidden_dim': 4,
    'l1_lambda': 0.05,
    'dropout_rate': 0.5,
    'epochs': 100,
    'lr': 0.01 
}

# Train the model and get predictions
y_labels_final, y_probs_final, y_preds_final, all_selected_indices = train_final_mlp_model(X_avg, y_avg, best_params)

# Save valid out-of-fold predictions to CSV
df_mlp_final = pd.DataFrame({
    'true_label': y_labels_final,
    'true_label': y_labels_final,
    'mlp_prob': y_probs_final,
    'mlp_pred': y_preds_final
})
# Out:
# Training Final MLP Model with Hyperparameters:
#   k_features:   10
#   hidden_dim:   4
#   l1_lambda:    0.05
#   dropout_rate: 0.5
#   epochs:       100
#   lr:           0.01
#
# Fold 1 complete.
# Fold 2 complete.
# Fold 3 complete.
# Fold 4 complete.
# Fold 5 complete.
#
# ...
# Final MLP Model Performance (5-Fold CV)
# ...
# True Cross-Validated Accuracy: 60.00%
# ROC-AUC: 0.5911
#
#               precision    recall  f1-score   support
#
#           TD       0.59      0.67      0.62        15
#          MLD       0.62      0.53      0.57        15
#
#     accuracy                           0.60        30
#    macro avg       0.60      0.60      0.60        30
# weighted avg       0.60      0.60      0.60        30

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix, classification_report

# Assuming helper_lin is your local module
from helper_lin import get_all_data, get_labels

def train_final_mlp_model(X_avg, y_avg, params):
    """Train the final MLP model using the optimized hyperparameters to prevent overfitting."""
    
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    
    all_test_preds = []
    all_test_labels = []
    all_test_probs = []
    all_selected_indices = []

    # --- NEW: Initialize arrays to hold metrics across all folds ---
    epochs = params['epochs']
    fold_train_losses = np.zeros((5, epochs))
    fold_val_losses = np.zeros((5, epochs))
    fold_train_accs = np.zeros((5, epochs))
    fold_val_accs = np.zeros((5, epochs))

    print(f"Training Final MLP Model with Hyperparameters:")
    print(f"  k_features:   {params['k_features']}")
    print(f"  hidden_dim:   {params['hidden_dim']}")
    print(f"  l1_lambda:    {params['l1_lambda']}")
    print(f"  dropout_rate: {params['dropout_rate']}")
    print(f"  epochs:       {params['epochs']}")
    print(f"  lr:           {params['lr']}\n")

    for fold, (train_idx, test_idx) in enumerate(skf.split(X_avg, y_avg)):
        
        # 1. Split Raw Data FIRST
        X_train_raw, X_test_raw = X_avg[train_idx], X_avg[test_idx]
        y_train, y_test = y_avg[train_idx], y_avg[test_idx]

        # 2. Feature Selection: Fit ONLY on training data
        selector = SelectKBest(score_func=f_classif, k=params['k_features'])
        X_train_reduced = selector.fit_transform(X_train_raw, y_train)
        X_test_reduced = selector.transform(X_test_raw) 
        
        # Store selected indices for this fold
        all_selected_indices.append(selector.get_support(indices=True))

        # 3. Scale the Data: Fit ONLY on training data
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train_reduced)
        X_test_scaled = scaler.transform(X_test_reduced)

        # 4. Convert to tensors
        X_train_t = torch.tensor(X_train_scaled, dtype=torch.float32)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
        X_test_t = torch.tensor(X_test_scaled, dtype=torch.float32)
        # NEW: Convert test labels to tensor for per-epoch validation loss calculation
        y_test_t = torch.tensor(y_test, dtype=torch.float32).view(-1, 1) 

        # 5. Build Model (with Dropout)
        model = nn.Sequential(
            nn.Linear(params['k_features'], params['hidden_dim']),
            nn.ReLU(),
            nn.Dropout(p=params['dropout_rate']),
            nn.Linear(params['hidden_dim'], 1),
            nn.Sigmoid()
        )

        criterion = nn.BCELoss()
        optimizer = optim.Adam(model.parameters(), lr=params['lr'])

        # 6. Training Loop
        for epoch in range(epochs):
            model.train() # Set to train mode
            optimizer.zero_grad()
            outputs = model(X_train_t)
            
            # Use pure BCE for tracking to ensure fair comparison with validation loss
            bce_loss = criterion(outputs, y_train_t) 

            # L1 penalty implementation: $$L_{Total} = L_{BCE} + \lambda \sum_{i} |w_{i}|$$
            l1_penalty = sum(torch.norm(p, 1) for p in model.parameters() if p.dim() > 1)
            total_loss = bce_loss + (params['l1_lambda'] * l1_penalty)

            total_loss.backward()
            optimizer.step()

            # --- NEW: Calculate Training Accuracy ---
            train_probs = outputs.detach().numpy().flatten()
            train_preds = (train_probs > 0.5).astype(int)
            train_acc = accuracy_score(y_train, train_preds)

            # --- NEW: Calculate Validation Metrics ---
            model.eval() # Set to eval mode to disable dropout
            with torch.no_grad():
                val_outputs = model(X_test_t)
                val_bce_loss = criterion(val_outputs, y_test_t)
                val_probs_epoch = val_outputs.numpy().flatten()
                val_preds_epoch = (val_probs_epoch > 0.5).astype(int)
                val_acc = accuracy_score(y_test, val_preds_epoch)

            # --- NEW: Store metrics for this epoch ---
            fold_train_losses[fold, epoch] = bce_loss.item() 
            fold_val_losses[fold, epoch] = val_bce_loss.item()
            fold_train_accs[fold, epoch] = train_acc
            fold_val_accs[fold, epoch] = val_acc

        # 7. Final Evaluation on test fold for overall metrics
        model.eval()
        with torch.no_grad():
            test_probs = model(X_test_t).numpy().flatten()
            test_preds = (test_probs > 0.5).astype(int)

            all_test_probs.extend(test_probs)
            all_test_preds.extend(test_preds)
            all_test_labels.extend(y_test)
        
        print(f"Fold {fold+1} complete.")

    # Convert to numpy arrays
    all_test_labels = np.array(all_test_labels)
    all_test_preds = np.array(all_test_preds)
    all_test_probs = np.array(all_test_probs)

    # --- NEW: Plot Average Learning Curves ---
    avg_train_loss = np.mean(fold_train_losses, axis=0)
    avg_val_loss = np.mean(fold_val_losses, axis=0)
    avg_train_acc = np.mean(fold_train_accs, axis=0)
    avg_val_acc = np.mean(fold_val_accs, axis=0)

    # 
    plt.figure(figsize=(14, 5))

    # Loss subplot
    plt.subplot(1, 2, 1)
    plt.plot(avg_train_loss, label='Train Loss (BCE)')
    plt.plot(avg_val_loss, label='Val Loss (BCE)')
    plt.title('Average Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(alpha=0.3)

    # Accuracy subplot
    plt.subplot(1, 2, 2)
    plt.plot(avg_train_acc, label='Train Accuracy')
    plt.plot(avg_val_acc, label='Val Accuracy')
    plt.title('Average Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(alpha=0.3)

    plt.tight_layout()
    plt.show()

    # Final evaluation metrics printing
    final_acc = accuracy_score(all_test_labels, all_test_preds)
    try:
        final_auc = roc_auc_score(all_test_labels, all_test_probs)
    except ValueError:
        final_auc = float('nan')

    print(f"\n{'='*70}")
    print(f"Final MLP Model Performance (5-Fold CV)")
    print(f"{'='*70}")
    print(f"True Cross-Validated Accuracy: {final_acc * 100:.2f}%")
    print(f"ROC-AUC: {final_auc:.4f}\n")
    print(classification_report(all_test_labels, all_test_preds, target_names=['TD', 'MLD']))

    # Confusion Matrix
    plt.figure(figsize=(6, 5))
    cm = confusion_matrix(all_test_labels, all_test_preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['TD', 'MLD'], yticklabels=['TD', 'MLD'],
                cbar_kws={'label': 'Count'})
    plt.title("Final MLP - Confusion Matrix")
    plt.ylabel("True Label")
    plt.xlabel("Predicted Label")
    plt.tight_layout()
    plt.show()

    # ROC Curve
    from sklearn.metrics import roc_curve, auc
    fpr, tpr, _ = roc_curve(all_test_labels, all_test_probs)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(7, 7))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.4f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve - Final MLP Model')
    plt.legend(loc="lower right")
    plt.grid(alpha=0.3)
    plt.show()

    return all_test_labels, all_test_probs, all_test_preds, all_selected_indices

# --- Execution ---
# (Your execution code remains exactly the same)
X_avg, y_avg = get_all_data()

# The top parameters from your grid search
# Note: The grid search output didn't list 'lr', so we're defaulting to 0.01 
# which was standard in your previous runs. You can change this to 0.005 if needed.
best_params = {
    'k_features': 10,
    'hidden_dim': 4,
    'l1_lambda': 0.05,
    'dropout_rate': 0.5,
    'epochs': 100,
    'lr': 0.01 
}

# Train the model and get predictions
y_labels_final, y_probs_final, y_preds_final, all_selected_indices = train_final_mlp_model(X_avg, y_avg, best_params)

# Save valid out-of-fold predictions to CSV
df_mlp_final = pd.DataFrame({
    'true_label': y_labels_final,
    'true_label': y_labels_final,
    'mlp_prob': y_probs_final,
    'mlp_pred': y_preds_final
})
# Out:
# Training Final MLP Model with Hyperparameters:
#   k_features:   10
#   hidden_dim:   4
#   l1_lambda:    0.05
#   dropout_rate: 0.5
#   epochs:       100
#   lr:           0.01
#
# Fold 1 complete.
# Fold 2 complete.
# Fold 3 complete.
# Fold 4 complete.
# Fold 5 complete.
# ...
# Final MLP Model Performance (5-Fold CV)
# ...
# True Cross-Validated Accuracy: 63.33%
# ROC-AUC: 0.6044
#
#               precision    recall  f1-score   support
#
#           TD       0.61      0.73      0.67        15
#          MLD       0.67      0.53      0.59        15
#
#     accuracy                           0.63        30
#    macro avg       0.64      0.63      0.63        30
# weighted avg       0.64      0.63      0.63        30

# %%
import torch.nn as nn
import torch.optim as optim
import torch

class GatedBrainMLP(nn.Module):
    def __init__(self, input_dim=100):
        super(GatedBrainMLP, self).__init__()
        
        # Learnable gating weights for each of the 100 input features
        # Initialized to 1.0 so all features start as fully "active"
        self.gates = nn.Parameter(torch.ones(input_dim))
        
        # Your standard MLP layers
        self.layer1 = nn.Linear(input_dim, 32) 
        self.relu = nn.ReLU()
        self.output = nn.Linear(32, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        # 1. Constrain gates to be between 0 and 1
        g = torch.clamp(self.gates, min=0.0, max=1.0)
        
        # 2. Multiply input features by the gate weights
        gated_x = x * g
        
        # 3. Pass through the normal MLP
        out = self.relu(self.layer1(gated_x))
        out = self.sigmoid(self.output(out))
        
        # Return both the prediction and the current gate values
        return out, g

# %%
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
import torch
import numpy as np

def train_gated_mlp_model(X_avg, y_avg):
    all_test_preds = []
    all_test_labels = []
    all_test_probs = []

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    print(f"Starting Stratified 5-Fold CV with Gating mechanism (Leakage Fixed)...")

    # Variables to hold the last fold's features/weights for returning
    final_feature_weights = None
    final_selected_indices = None

    for fold, (train_idx, test_idx) in enumerate(skf.split(X_avg, y_avg)):
        # 1. SPLIT DATA FIRST
        X_train_raw, X_test_raw = X_avg[train_idx], X_avg[test_idx]
        y_train, y_test = y_avg[train_idx], y_avg[test_idx]

        # 2. FIT FEATURE SELECTION ON TRAINING DATA ONLY
        selector = SelectKBest(score_func=f_classif, k=100)
        X_train_reduced = selector.fit_transform(X_train_raw, y_train)
        X_test_reduced = selector.transform(X_test_raw) # Only transform the test data
        selected_indices = selector.get_support(indices=True)

        # 3. FIT SCALER ON TRAINING DATA ONLY
        scaler = StandardScaler()
        X_train_final = scaler.fit_transform(X_train_reduced)
        X_test_final = scaler.transform(X_test_reduced) # Only transform the test data

        # 4. Convert to Tensors
        X_train_t = torch.tensor(X_train_final, dtype=torch.float32)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
        X_test_t = torch.tensor(X_test_final, dtype=torch.float32)

        # Initialize the new Gated model and optimizer
        model = GatedBrainMLP(input_dim=100) 
        criterion = torch.nn.BCELoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
        
        # Adjust this up or down to control how many ROIs get pushed to zero
        l1_lambda = 0.05 

        # Train on the training folds
        model.train()
        for epoch in range(100):
            optimizer.zero_grad()
            
            # Forward pass returns both predictions and gates
            outputs, gates = model(X_train_t)
            
            bce_loss = criterion(outputs, y_train_t)
            
            # Apply L1 penalty directly to the gates 
            l1_penalty = torch.sum(torch.abs(gates))
            total_loss = bce_loss + (l1_lambda * l1_penalty)
            
            total_loss.backward()
            optimizer.step()

        # Test on the test fold
        model.eval()
        with torch.no_grad():
            test_probs_t, _ = model(X_test_t) # Unpack the tuple
            
            preds = (test_probs_t > 0.5).float().numpy().flatten()
            
            all_test_probs.extend(test_probs_t.numpy().flatten())
            all_test_preds.extend(preds)
            all_test_labels.extend(y_test)
        
        # Save the indices and weights of the current fold
        final_selected_indices = selected_indices
        final_feature_weights = model.gates.detach().cpu().numpy()
        
        print(f"Fold {fold+1} complete.")

    final_acc = accuracy_score(all_test_labels, all_test_preds)
    print(f"\nFinal Stratified K-Fold Accuracy: {final_acc * 100:.2f}%")
    
    # Note: Returns the selected indices and feature weights from the LAST fold.
    return all_test_labels, all_test_probs, all_test_preds, final_feature_weights, final_selected_indices

# %%
X_avg, y_avg = get_all_data()
all_test_labels, all_test_probs, all_test_preds, feature_weights, selected_indices = train_gated_mlp_model(X_avg, y_avg)
# Out:
# Starting Stratified 5-Fold CV with Gating mechanism (Leakage Fixed)...
# Fold 1 complete.
# Fold 2 complete.
# Fold 3 complete.
# Fold 4 complete.
# Fold 5 complete.
#
# Final Stratified K-Fold Accuracy: 53.33%

# %%
plt_roc_curve(all_test_labels, all_test_probs)

# %%
mult_top_10_conn = get_top_10_conn(feature_weights, selected_indices)
# Out:
# --- Top 10 Connectivity Fingerprints ---
# [fetch_atlas_schaefer_2018] Dataset found in /Users/jchong058/nilearn_data/schaefer_2018
# Rank 1: Score 0.0572 | 7Networks_RH_DorsAttn_Post_18 <-> 7Networks_RH_Default_PFCv_2
# Rank 2: Score 0.0568 | 7Networks_LH_SomMot_10 <-> 7Networks_RH_SomMot_20
# Rank 3: Score 0.0408 | 7Networks_LH_DorsAttn_Post_12 <-> 7Networks_RH_Default_Par_2
# Rank 4: Score 0.0386 | 7Networks_LH_SomMot_10 <-> 7Networks_RH_SomMot_39
# Rank 5: Score 0.0373 | 7Networks_LH_Default_pCunPCC_10 <-> 7Networks_RH_Default_pCunPCC_3
# Rank 6: Score 0.0370 | 7Networks_LH_Cont_PFCv_1 <-> 7Networks_RH_Cont_Par_2
# Rank 7: Score 0.0367 | 7Networks_LH_Default_Par_1 <-> 7Networks_RH_Vis_2
# Rank 8: Score 0.0343 | 7Networks_RH_Vis_26 <-> 7Networks_RH_DorsAttn_Post_9
# Rank 9: Score 0.0342 | 7Networks_LH_DorsAttn_Post_4 <-> 7Networks_RH_Cont_Cing_1
# Rank 10: Score 0.0342 | 7Networks_RH_SomMot_12 <-> 7Networks_RH_Default_PFCdPFCm_11

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold

# (Assuming GatedBrainMLP is defined elsewhere in your code)

def train_gated_mlp_model(X_avg, y_avg):
    all_test_preds = []
    all_test_labels = []
    all_test_probs = []

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    print(f"Starting Stratified 5-Fold CV with Gating mechanism (Leakage Fixed)...")

    # Variables to hold the last fold's features/weights for returning
    final_feature_weights = None
    final_selected_indices = None

    # --- NEW: Initialize arrays to hold metrics across all folds ---
    epochs = 100
    fold_train_losses = np.zeros((5, epochs))
    fold_val_losses = np.zeros((5, epochs))
    fold_train_accs = np.zeros((5, epochs))
    fold_val_accs = np.zeros((5, epochs))

    for fold, (train_idx, test_idx) in enumerate(skf.split(X_avg, y_avg)):
        # 1. SPLIT DATA FIRST
        X_train_raw, X_test_raw = X_avg[train_idx], X_avg[test_idx]
        y_train, y_test = y_avg[train_idx], y_avg[test_idx]

        # 2. FIT FEATURE SELECTION ON TRAINING DATA ONLY
        selector = SelectKBest(score_func=f_classif, k=100)
        X_train_reduced = selector.fit_transform(X_train_raw, y_train)
        X_test_reduced = selector.transform(X_test_raw) # Only transform the test data
        selected_indices = selector.get_support(indices=True)

        # 3. FIT SCALER ON TRAINING DATA ONLY
        scaler = StandardScaler()
        X_train_final = scaler.fit_transform(X_train_reduced)
        X_test_final = scaler.transform(X_test_reduced) # Only transform the test data

        # 4. Convert to Tensors
        X_train_t = torch.tensor(X_train_final, dtype=torch.float32)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
        X_test_t = torch.tensor(X_test_final, dtype=torch.float32)
        # NEW: Convert test labels to tensor for per-epoch validation evaluation
        y_test_t = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

        # Initialize the new Gated model and optimizer
        model = GatedBrainMLP(input_dim=100) 
        criterion = torch.nn.BCELoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
        
        # Adjust this up or down to control how many ROIs get pushed to zero
        l1_lambda = 0.05 

        # Train on the training folds
        for epoch in range(epochs):
            model.train() # Ensure model is in train mode
            optimizer.zero_grad()
            
            # Forward pass returns both predictions and gates
            outputs, gates = model(X_train_t)
            
            # Pure BCE loss for tracking
            bce_loss = criterion(outputs, y_train_t)
            
            # Apply L1 penalty directly to the gates 
            l1_penalty = torch.sum(torch.abs(gates))
            total_loss = bce_loss + (l1_lambda * l1_penalty)
            
            total_loss.backward()
            optimizer.step()

            # --- NEW: Calculate Training Accuracy ---
            train_probs = outputs.detach().numpy().flatten()
            train_preds = (train_probs > 0.5).astype(int)
            train_acc = accuracy_score(y_train, train_preds)

            # --- NEW: Calculate Validation Metrics ---
            model.eval() # Set to eval mode
            with torch.no_grad():
                val_outputs, _ = model(X_test_t) # Unpack tuple
                val_bce_loss = criterion(val_outputs, y_test_t)
                val_probs_epoch = val_outputs.numpy().flatten()
                val_preds_epoch = (val_probs_epoch > 0.5).astype(int)
                val_acc = accuracy_score(y_test, val_preds_epoch)

            # --- NEW: Store metrics for this epoch ---
            fold_train_losses[fold, epoch] = bce_loss.item() 
            fold_val_losses[fold, epoch] = val_bce_loss.item()
            fold_train_accs[fold, epoch] = train_acc
            fold_val_accs[fold, epoch] = val_acc

        # Test on the test fold for final overall metrics
        model.eval()
        with torch.no_grad():
            test_probs_t, _ = model(X_test_t) # Unpack the tuple
            
            preds = (test_probs_t > 0.5).float().numpy().flatten()
            
            all_test_probs.extend(test_probs_t.numpy().flatten())
            all_test_preds.extend(preds)
            all_test_labels.extend(y_test)
        
        # Save the indices and weights of the current fold
        final_selected_indices = selected_indices
        final_feature_weights = model.gates.detach().cpu().numpy()
        
        print(f"Fold {fold+1} complete.")

    final_acc = accuracy_score(all_test_labels, all_test_preds)
    print(f"\nFinal Stratified K-Fold Accuracy: {final_acc * 100:.2f}%")

    
    # --- NEW: Plot Average Learning Curves ---
    avg_train_loss = np.mean(fold_train_losses, axis=0)
    avg_val_loss = np.mean(fold_val_losses, axis=0)
    avg_train_acc = np.mean(fold_train_accs, axis=0)
    avg_val_acc = np.mean(fold_val_accs, axis=0)

    plt.figure(figsize=(14, 5))

    # Loss subplot
    plt.subplot(1, 2, 1)
    plt.plot(avg_train_loss, label='Train Loss (BCE)')
    plt.plot(avg_val_loss, label='Val Loss (BCE)')
    plt.title('Gated MLP: Avg Training vs Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(alpha=0.3)

    # Accuracy subplot
    plt.subplot(1, 2, 2)
    plt.plot(avg_train_acc, label='Train Accuracy')
    plt.plot(avg_val_acc, label='Val Accuracy')
    plt.title('Gated MLP: Avg Training vs Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(alpha=0.3)

    plt.tight_layout()
    plt.show()
    
    # Note: Returns the selected indices and feature weights from the LAST fold.
    return all_test_labels, all_test_probs, all_test_preds, final_feature_weights, final_selected_indices
X_avg, y_avg = get_all_data()
all_test_labels, all_test_probs, all_test_preds, feature_weights, selected_indices = train_gated_mlp_model(X_avg, y_avg)
# Out:
# Starting Stratified 5-Fold CV with Gating mechanism (Leakage Fixed)...
# Fold 1 complete.
# Fold 2 complete.
# Fold 3 complete.
# Fold 4 complete.
# Fold 5 complete.
#
# Final Stratified K-Fold Accuracy: 50.00%

# %%
plt_confusion_matrix(all_test_labels, all_test_preds)
# Out:
# Detailed Classification Report:
#                           precision    recall  f1-score   support
#
#      Typical Development       0.50      0.60      0.55        15
# Math Learning Difficulty       0.50      0.40      0.44        15
#
#                 accuracy                           0.50        30
#                macro avg       0.50      0.50      0.49        30
#             weighted avg       0.50      0.50      0.49        30

# %%
plt_roc_curve(all_test_labels, all_test_probs)

# %% [markdown]
# # Save MLP All results

# %%
import pandas as pd

# Convert the list of tensors to a flat numpy array
mlp_probs = np.array([p.item() for p in all_test_probs])
mlp_labels = np.array(all_test_labels)

df_mlp = pd.DataFrame({
    'true_label': mlp_labels,
    'mlp_prob': mlp_probs
})
df_mlp.to_csv('preds/mlp_kfold_results.csv', index=False)
